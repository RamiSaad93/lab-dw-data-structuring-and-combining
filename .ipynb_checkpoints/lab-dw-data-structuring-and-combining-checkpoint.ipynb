# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
import pandas as pd
url1 = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv"
url2 = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv"
url3 = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv"
    
df1 = pd.read_csv(url1)
df2 = pd.read_csv(url2)
df3 = pd.read_csv(url3)

# %%
df1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
df3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
print(df1.columns)
print(df2.columns)
print(df3.columns)
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
df3.columns = ['Customer', 'ST', 'Customer Lifetime Value', 'Education', 'GENDER',
       'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
       'Policy Type', 'Total Claim Amount', 'Vehicle Class']

# %%
new_df = pd.concat([df1,df2,df3])
new_df
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
new_df.isna().any()
# Out:
# Customer                     True
# ST                           True
# GENDER                       True
# Education                    True
# Customer Lifetime Value      True
# Income                       True
# Monthly Premium Auto         True
# Number of Open Complaints    True
# Policy Type                  True
# Vehicle Class                True
# Total Claim Amount           True
# dtype: bool

# %%
new_df.isna().sum()
# Out:
# Customer                     2937
# ST                           2937
# GENDER                       3059
# Education                    2937
# Customer Lifetime Value      2944
# Income                       2937
# Monthly Premium Auto         2937
# Number of Open Complaints    2937
# Policy Type                  2937
# Vehicle Class                2937
# Total Claim Amount           2937
# dtype: int64

# %%
new_df.dropna(how = "all", inplace = True)

# %%
new_df.shape
# Out:
# (9137, 11)

# %%
new_df.isna().any()
# Out:
# Customer                     False
# ST                           False
# GENDER                        True
# Education                    False
# Customer Lifetime Value       True
# Income                       False
# Monthly Premium Auto         False
# Number of Open Complaints    False
# Policy Type                  False
# Vehicle Class                False
# Total Claim Amount           False
# dtype: bool

# %%
new_df.isna().sum()
# Out:
# Customer                       0
# ST                             0
# GENDER                       122
# Education                      0
# Customer Lifetime Value        7
# Income                         0
# Monthly Premium Auto           0
# Number of Open Complaints      0
# Policy Type                    0
# Vehicle Class                  0
# Total Claim Amount             0
# dtype: int64

# %%
new_df.dtypes
# Out:
# Customer                      object
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value       object
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints     object
# Policy Type                   object
# Vehicle Class                 object
# Total Claim Amount           float64
# dtype: object

# %%
new_df["Customer Lifetime Value"] = new_df["Customer Lifetime Value"].apply(lambda x: x.strip("%") if isinstance(x,str) else x)

# %%
new_df
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                  697953.59      0.0                  94.0
# 2                 1288743.17  48767.0                 108.0
# ...

# %%
new_df.dtypes
# Out:
# Customer                      object
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value       object
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints     object
# Policy Type                   object
# Vehicle Class                 object
# Total Claim Amount           float64
# dtype: object

# %%
new_df["Customer Lifetime Value"] = new_df["Customer Lifetime Value"].apply(float)

# %%
new_df["Number of Open Complaints"] = new_df["Number of Open Complaints"].apply(lambda x: x.split("/")[1] if isinstance(x,str) else x)

# %%
#new_df["Number of Open Complaints"] = new_df["Number of Open Complaints"].str.split("/").str[1]

# %%
new_df["Number of Open Complaints"] = new_df["Number of Open Complaints"].apply(int)

# %%
new_df.dtypes
# Out:
# Customer                      object
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value      float64
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints      int64
# Policy Type                   object
# Vehicle Class                 object
# Total Claim Amount           float64
# dtype: object

# %%
new_df
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                         NaN      0.0                1000.0
# 1                6.979536e+05      0.0                  94.0
# 2                1.288743e+06  48767.0                 108.0
# ...

# %%
new_df['Customer Lifetime Value'].fillna(new_df['Customer Lifetime Value'].mean(), inplace=True)

# %%
new_df.isna().sum()
# Out:
# Customer                       0
# ST                             0
# GENDER                       122
# Education                      0
# Customer Lifetime Value        0
# Income                         0
# Monthly Premium Auto           0
# Number of Open Complaints      0
# Policy Type                    0
# Vehicle Class                  0
# Total Claim Amount             0
# dtype: int64

# %%
new_df.GENDER.value_counts()
# Out:
# F         4560
# M         4368
# Male        40
# female      30
# Femal       17
# Name: GENDER, dtype: int64

# %%
gender_dict = {"Male":"M", "female":"F", "Femal":"F", "F":"F", "M":"M"}
new_df.GENDER = new_df.GENDER.map(gender_dict)

new_df.GENDER.value_counts()
# Out:
# F    4607
# M    4408
# Name: GENDER, dtype: int64

# %%
new_df.GENDER.isna()
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7065    False
# 7066    False
# 7067    False
# 7068    False
# 7069    False
# Name: GENDER, Length: 9137, dtype: bool

# %%
new_df.GENDER.fillna(method = "bfill", inplace = True)

# %%
new_df.isna().sum()
# Out:
# Customer                     0
# ST                           0
# GENDER                       0
# Education                    0
# Customer Lifetime Value      0
# Income                       0
# Monthly Premium Auto         0
# Number of Open Complaints    0
# Policy Type                  0
# Vehicle Class                0
# Total Claim Amount           0
# dtype: int64

# %%
new_df.GENDER.value_counts()
# Out:
# F    4683
# M    4454
# Name: GENDER, dtype: int64

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
url = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv"
df = pd.read_csv(url)
df
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877  California              6857.519928       No
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
df.columns
# Out:
# Index(['unnamed:_0', 'customer', 'state', 'customer_lifetime_value',
#        'response', 'coverage', 'education', 'effective_to_date',
#        'employmentstatus', 'gender', 'income', 'location_code',
#        'marital_status', 'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'total_claim_amount', 'vehicle_class', 'vehicle_size',
#        'vehicle_type', 'month'],
#       dtype='object')

# %%
df.drop("unnamed:_0", axis = 1, inplace = True)

# %%
df
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877  California              6857.519928       No     Basic
#
#       education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
df.dtypes
# Out:
# customer                          object
# state                             object
# customer_lifetime_value          float64
# response                          object
# coverage                          object
# education                         object
# effective_to_date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location_code                     object
# marital_status                    object
# monthly_premium_auto               int64
# months_since_last_claim          float64
# months_since_policy_inception      int64
# number_of_open_complaints        float64
# number_of_policies                 int64
# policy_type                       object
# policy                            object
# renew_offer_type                  object
# sales_channel                     object
# total_claim_amount               float64
# vehicle_class                     object
# ...

# %%
df.months_since_last_claim.unique()
# Out:
# array([ 7.        ,  3.        , 34.        , 10.        , 15.14907074,
#         2.        ,  8.        , 35.        , 33.        , 19.        ,
#        13.        ,  5.        , 24.        , 25.        ,  6.        ,
#        20.        , 26.        , 14.        ,  9.        , 29.        ,
#        11.        ,  1.        , 18.        , 16.        , 30.        ,
#        12.        ,  4.        , 22.        , 31.        , 21.        ,
#        28.        , 17.        , 15.        , 32.        , 23.        ,
#        27.        ,  0.        ])

# %%
df.months_since_last_claim = df.months_since_last_claim.apply(lambda x: round(x))

# %%
df.months_since_last_claim.unique()
# Out:
# array([ 7,  3, 34, 10, 15,  2,  8, 35, 33, 19, 13,  5, 24, 25,  6, 20, 26,
#        14,  9, 29, 11,  1, 18, 16, 30, 12,  4, 22, 31, 21, 28, 17, 32, 23,
#        27,  0], dtype=int64)

# %%
df.dtypes
# Out:
# customer                          object
# state                             object
# customer_lifetime_value          float64
# response                          object
# coverage                          object
# education                         object
# effective_to_date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location_code                     object
# marital_status                    object
# monthly_premium_auto               int64
# months_since_last_claim            int64
# months_since_policy_inception      int64
# number_of_open_complaints        float64
# number_of_policies                 int64
# policy_type                       object
# policy                            object
# renew_offer_type                  object
# sales_channel                     object
# total_claim_amount               float64
# vehicle_class                     object
# ...

# %%
df.number_of_open_complaints.value_counts()
# Out:
# 0.000000    8160
# 1.000000    1145
# 0.384256     633
# 2.000000     414
# 3.000000     324
# 4.000000     166
# 5.000000      68
# Name: number_of_open_complaints, dtype: int64

# %%
df.number_of_open_complaints = df.number_of_open_complaints.apply(lambda x: round(x))

# %%
df.number_of_open_complaints.value_counts()
# Out:
# 0    8793
# 1    1145
# 2     414
# 3     324
# 4     166
# 5      68
# Name: number_of_open_complaints, dtype: int64

# %%
df.nunique()
# Out:
# customer                         9134
# state                               5
# customer_lifetime_value          8041
# response                            2
# coverage                            3
# education                           5
# effective_to_date                  59
# employmentstatus                    5
# gender                              2
# income                           5694
# location_code                       3
# marital_status                      3
# monthly_premium_auto              202
# months_since_last_claim            36
# months_since_policy_inception     100
# number_of_open_complaints           6
# number_of_policies                  9
# policy_type                         3
# policy                              9
# renew_offer_type                    4
# sales_channel                       4
# total_claim_amount               5106
# vehicle_class                       6
# vehicle_size                        3
# vehicle_type                        1
# ...

# %%
df.state.unique()
# Out:
# array(['Arizona', 'California', 'Washington', 'Oregon', 'Nevada'],
#       dtype=object)

# %%
df.coverage.unique()
# Out:
# array(['Basic', 'Extended', 'Premium'], dtype=object)

# %%
df.education.unique()
# Out:
# array(['College', 'Bachelor', 'High School or Below', 'Doctor', 'Master'],
#       dtype=object)

# %%
def unique_values(dataframe):
    dict = {}
    for x in dataframe.columns:
        dict[x] = dataframe[x].unique() 
        
    return dict
    
unique_values(df)
# Out:
# {'customer': array(['DK49336', 'KX64629', 'LZ68649', ..., 'KX53892', 'TL39050',
#         'WA60547'], dtype=object),
#  'state': array(['Arizona', 'California', 'Washington', 'Oregon', 'Nevada'],
#        dtype=object),
#  'customer_lifetime_value': array([ 4809.21696 ,  2228.525238, 14947.9173  , ...,  5259.444853,
#         23893.3041  , 11971.97765 ]),
#  'response': array(['No', 'Yes'], dtype=object),
#  'coverage': array(['Basic', 'Extended', 'Premium'], dtype=object),
#  'education': array(['College', 'Bachelor', 'High School or Below', 'Doctor', 'Master'],
#        dtype=object),
#  'effective_to_date': array(['2011-02-18', '2011-01-18', '2011-02-10', '2011-01-11',
#         '2011-01-17', '2011-02-14', '2011-02-24', '2011-01-19',
#         '2011-01-04', '2011-01-02', '2011-02-07', '2011-01-31',
#         '2011-01-26', '2011-02-28', '2011-01-16', '2011-02-26',
#         '2011-02-23', '2011-01-15', '2011-02-02', '2011-02-15',
# ...

# %%
df.total_claim_amount = df.total_claim_amount.apply(lambda x: round(x,2))

# %%
df.customer_lifetime_value = df.customer_lifetime_value.apply(lambda x: round(x,2))

# %%
df.customer_lifetime_value.unique()
# Out:
# array([ 4809.22,  2228.53, 14947.92, ...,  5259.44, 23893.3 , 11971.98])

# %%
df.total_claim_amount.unique()
# Out:
# array([292.8 , 744.92, 480.  , ..., 273.02, 381.31, 618.29])

# %%
df.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size', 'vehicle_type', 'month'],
#       dtype='object')

# %%
df.isna().any()
# Out:
# customer                         False
# state                            False
# customer_lifetime_value          False
# response                         False
# coverage                         False
# education                        False
# effective_to_date                False
# employmentstatus                 False
# gender                           False
# income                           False
# location_code                    False
# marital_status                   False
# monthly_premium_auto             False
# months_since_last_claim          False
# months_since_policy_inception    False
# number_of_open_complaints        False
# number_of_policies               False
# policy_type                      False
# policy                           False
# renew_offer_type                 False
# sales_channel                    False
# total_claim_amount               False
# vehicle_class                    False
# vehicle_size                     False
# ...

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %%
pivot_df = df.pivot_table(index='sales_channel', values=['total_claim_amount'], aggfunc='sum')

# %%
pivot_df
# Out:
#                total_claim_amount
# sales_channel
# Agent                  1810226.88
# Branch                 1301204.34
# Call Center             926601.02
# Web                     706600.02

# %%
df2 = df.copy()

# %%
df
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona                  4809.22       No     Basic
# 1      KX64629  California                  2228.53       No     Basic
# 2      LZ68649  Washington                 14947.92       No     Basic
# 3      XL78013      Oregon                 22332.44      Yes  Extended
# 4      QA50777      Oregon                  9025.07       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada                 15563.37       No   Premium
# 10906  KX53892      Oregon                  5259.44       No     Basic
# 10907  TL39050     Arizona                 23893.30       No  Extended
# 10908  WA60547  California                 11971.98       No   Premium
# 10909  IV32877  California                  6857.52       No     Basic
#
#       education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
df2
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona                  4809.22       No     Basic
# 1      KX64629  California                  2228.53       No     Basic
# 2      LZ68649  Washington                 14947.92       No     Basic
# 3      XL78013      Oregon                 22332.44      Yes  Extended
# 4      QA50777      Oregon                  9025.07       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada                 15563.37       No   Premium
# 10906  KX53892      Oregon                  5259.44       No     Basic
# 10907  TL39050     Arizona                 23893.30       No  Extended
# 10908  WA60547  California                 11971.98       No   Premium
# 10909  IV32877  California                  6857.52       No     Basic
#
#       education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
df2['revenue'] = df2['customer_lifetime_value'] - df2['total_claim_amount']

# %%
pivot_df2 = df2.pivot_table(index='sales_channel', values=['revenue'], aggfunc='sum')

# %%
pivot_df2
# Out:
#                    revenue
# sales_channel
# Agent          31247660.76
# Branch         23057996.95
# Call Center    16437687.33
# Web            11991033.02

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
pivot_df_2 = df.pivot_table(index= 'gender', columns = 'education', values = 'customer_lifetime_value', aggfunc = 'mean')

# %%
pivot_df_2
# Out:
# education     Bachelor      College       Doctor  High School or Below  \
# gender
# F          7874.269547  7748.823526  7328.508650           8675.220038
# M          7703.601609  8052.459430  7415.333532           8149.687629
#
# education       Master
# gender
# F          8157.053137
# M          8168.832670

# %%
pivot_df_2 = pivot_df_2.round(2)

# %%
pivot_df_2
# Out:
# education  Bachelor  College   Doctor  High School or Below   Master
# gender
# F           7874.27  7748.82  7328.51               8675.22  8157.05
# M           7703.60  8052.46  7415.33               8149.69  8168.83

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
df_index = df.copy()

# %%
df_index
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona                  4809.22       No     Basic
# 1      KX64629  California                  2228.53       No     Basic
# 2      LZ68649  Washington                 14947.92       No     Basic
# 3      XL78013      Oregon                 22332.44      Yes  Extended
# 4      QA50777      Oregon                  9025.07       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada                 15563.37       No   Premium
# 10906  KX53892      Oregon                  5259.44       No     Basic
# 10907  TL39050     Arizona                 23893.30       No  Extended
# 10908  WA60547  California                 11971.98       No   Premium
# 10909  IV32877  California                  6857.52       No     Basic
#
#       education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
df_long
# Out:
#                         variable  value
# 0      number_of_open_complaints      0
# 1      number_of_open_complaints      0
# 2      number_of_open_complaints      0
# 3      number_of_open_complaints      0
# 4      number_of_open_complaints      0
# ...                          ...    ...
# 10905  number_of_open_complaints      0
# 10906  number_of_open_complaints      0
# 10907  number_of_open_complaints      0
# 10908  number_of_open_complaints      4
# 10909  number_of_open_complaints      0
#
# [10910 rows x 2 columns]

# %%
df_long = pd.melt(df, id_vars = ['number_of_open_complaints'], value_vars = ['policy_type', 'month'], var_name = '', value_name = '')

# %%
df_long
# Out:
#        number_of_open_complaints
# 0                              0  policy_type  policy_type
# 1                              0  policy_type  policy_type
# 2                              0  policy_type  policy_type
# 3                              0  policy_type  policy_type
# 4                              0  policy_type  policy_type
# ...                          ...          ...          ...
# 21815                          0        month        month
# 21816                          0        month        month
# 21817                          0        month        month
# 21818                          4        month        month
# 21819                          0        month        month
#
# [21820 rows x 3 columns]

# %%
long_df_2
# Out:
#           policy_type                   variable  value
# 0      Corporate Auto  number_of_open_complaints      0
# 1       Personal Auto  number_of_open_complaints      0
# 2       Personal Auto  number_of_open_complaints      0
# 3      Corporate Auto  number_of_open_complaints      0
# 4       Personal Auto  number_of_open_complaints      0
# ...               ...                        ...    ...
# 21815   Personal Auto                      month      1
# 21816   Personal Auto                      month      1
# 21817  Corporate Auto                      month      2
# 21818   Personal Auto                      month      2
# 21819   Personal Auto                      month      1
#
# [21820 rows x 3 columns]

# %%
pivot_df_3 = df.pivot_table(index = 'policy_type',columns = 'month', values = 'number_of_open_complaints', aggfunc = 'sum')
pivot_df_3
# Out:
# month              1     2
# policy_type
# Corporate Auto   415   361
# Personal Auto   1635  1363
# Special Auto      84    91
